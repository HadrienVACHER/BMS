# %%
import wandb
import pandas as pd

api = wandb.Api()
run = api.run("CCDS_NTU/adjoint_sampler/runs/yha6q6xz")

df = run.history(samples=5000)
print(df.columns.tolist())
print(run.summary)
print(df.head(10))
print(df.tail(10))

filename = f'/Users/hadrienvacher/Desktop/NTU/Code/BMS/wandb_history_{run.name}.csv'
df.to_csv(filename, index=False)
# Out:
# ['adjoint_buffer_size', '_step', 'eq_w2', 'dist_w2', '_runtime', 'energy_w2', '_timestamp', 'adjoint_loss']
# {'_step': 4999, 'eq_w2': 0.9386249780654908, 'dist_w2': 0.1854280254879782, '_runtime': 9891.942237553, 'energy_w2': 0.3076655502322741, '_timestamp': 1788522440.574603, 'adjoint_loss': 6.610814094543457, '_wandb.runtime': 9891, 'adjoint_buffer_size': 10000}
#    adjoint_buffer_size  _step     eq_w2  dist_w2    _runtime  energy_w2  \
# 0                  512      0  1.507923  0.54894   86.327576  46.254077
# 1                 1024      1       NaN      NaN   87.910757        NaN
# 2                 1536      2       NaN      NaN   89.486917        NaN
# 3                 2048      3       NaN      NaN   91.069087        NaN
# 4                 2560      4       NaN      NaN   92.648150        NaN
# 5                 3072      5       NaN      NaN   94.219128        NaN
# 6                 3584      6       NaN      NaN   95.796259        NaN
# ...
