# %%
import wandb
import pandas as pd

api = wandb.Api()
run = api.run("/CCDS_NTU/BMS/runs/cpu0jklj")

df = run.history(samples=5000)
print(df.columns.tolist())
print(run.summary)
print(df.head(10))
print(df.tail(10))

filename = f'/Users/hadrienvacher/Desktop/NTU/Code/BMS/wandb_history_{run.name}.csv'
df.to_csv(filename, index=False)
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /Users/hadrienvacher/.netrc.
# ['energy_w2', 'eq_w2', 'adjoint_loss', '_step', '_runtime', 'adjoint_buffer_size', 'dist_w2', '_timestamp']
# {'_step': 1300, 'eq_w2': 1.4178701639175415, 'dist_w2': 0.4674422684800114, '_runtime': 3181.66471673, 'energy_w2': 3.3970948986377767, '_timestamp': 1788772398.9691768, 'adjoint_loss': 26.575668334960938, '_wandb.runtime': 3181, 'adjoint_buffer_size': 10000}
#     energy_w2    eq_w2  adjoint_loss  _step    _runtime  adjoint_buffer_size  \
# 0  146.057767  1.95703   1922.287598      0   85.543236                  512
# 1         NaN      NaN   1620.389404      1   87.346543                 1024
# 2         NaN      NaN   1071.081055      2   88.937500                 1536
# 3         NaN      NaN    803.811462      3   90.542497                 2048
# 4         NaN      NaN    650.412109      4   92.147519                 2560
# 5         NaN      NaN    546.018921      5   93.730219                 3072
# 6         NaN      NaN    468.968903      6   95.335623                 3584
# 7         NaN      NaN    416.183319      7   97.044770                 4096
# 8         NaN      NaN    372.421631      8   98.621577                 4608
# 9         NaN      NaN    335.187866      9  100.214723                 5120
#
#     dist_w2    _timestamp
# 0  1.116444  1.788769e+09
# 1       NaN  1.788769e+09
# 2       NaN  1.788769e+09
# 3       NaN  1.788769e+09
# 4       NaN  1.788769e+09
# 5       NaN  1.788769e+09
# 6       NaN  1.788769e+09
# 7       NaN  1.788769e+09
# 8       NaN  1.788769e+09
# 9       NaN  1.788769e+09
#       energy_w2  eq_w2  adjoint_loss  _step     _runtime  adjoint_buffer_size  \
# 1291        NaN    NaN     27.540443   1291  3111.231636                10000
# 1292        NaN    NaN     26.966812   1292  3112.779363                10000
# 1293        NaN    NaN     26.612795   1293  3114.335869                10000
# 1294        NaN    NaN     26.382790   1294  3115.889900                10000
# 1295        NaN    NaN     26.885286   1295  3117.442631                10000
# 1296        NaN    NaN     26.514000   1296  3118.994602                10000
# 1297        NaN    NaN     26.203686   1297  3120.551752                10000
# 1298        NaN    NaN     26.480556   1298  3122.101734                10000
# 1299        NaN    NaN     26.566730   1299  3123.645173                10000
# 1300        NaN    NaN     26.575668   1300  3181.664717                10000
#
#       dist_w2    _timestamp
# 1291      NaN  1.788772e+09
# 1292      NaN  1.788772e+09
# 1293      NaN  1.788772e+09
# 1294      NaN  1.788772e+09
# 1295      NaN  1.788772e+09
# 1296      NaN  1.788772e+09
# 1297      NaN  1.788772e+09
# 1298      NaN  1.788772e+09
# 1299      NaN  1.788772e+09
# 1300      NaN  1.788772e+09
