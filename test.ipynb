# %%
import wandb
import pandas as pd

api = wandb.Api()
run = api.run("/CCDS_NTU/BMS/runs/8fhsmafi")

df = run.history(samples=5000)
print(df.columns.tolist())
print(run.summary)
print(df.head(10))
print(df.tail(10))

filename = f'/Users/hadrienvacher/Desktop/NTU/Code/BMS/wandb_history_{run.name}.csv'
df.to_csv(filename, index=False)
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /Users/hadrienvacher/.netrc.
# ['energy_w2', 'eq_w2', 'adjoint_loss', '_step', '_runtime', 'adjoint_buffer_size', 'dist_w2', '_timestamp']
# {'_step': 999, 'eq_w2': 1.216747164726257, 'dist_w2': 0.2947079136928379, '_runtime': 1973.408643921, 'energy_w2': 5.159663413059726, '_timestamp': 1788766348.230774, 'adjoint_loss': 26.717937469482425, '_wandb.runtime': 1973, 'adjoint_buffer_size': 10000}
#     energy_w2     eq_w2  adjoint_loss  _step   _runtime  adjoint_buffer_size  \
# 0  167.982928  2.113073   1850.252808      0  83.866523                  512
# 1         NaN       NaN   1666.075317      1  85.646420                 1024
# 2         NaN       NaN   1103.031372      2  87.213913                 1536
# 3         NaN       NaN    826.361023      3  88.777873                 2048
# 4         NaN       NaN    668.806702      4  90.339832                 2560
# 5         NaN       NaN    560.986938      5  91.904225                 3072
# 6         NaN       NaN    482.053101      6  93.469263                 3584
# 7         NaN       NaN    427.085419      7  95.160854                 4096
# 8         NaN       NaN    382.092102      8  96.723472                 4608
# 9         NaN       NaN    342.313934      9  98.279998                 5120
#
#    dist_w2    _timestamp
# 0  1.46897  1.788764e+09
# 1      NaN  1.788764e+09
# 2      NaN  1.788764e+09
# 3      NaN  1.788764e+09
# 4      NaN  1.788764e+09
# 5      NaN  1.788764e+09
# 6      NaN  1.788764e+09
# 7      NaN  1.788764e+09
# 8      NaN  1.788764e+09
# 9      NaN  1.788764e+09
#      energy_w2  eq_w2  adjoint_loss  _step     _runtime  adjoint_buffer_size  \
# 990        NaN    NaN     27.809040    990  1960.625750                10000
# 991        NaN    NaN     27.897356    991  1962.183209                10000
# 992        NaN    NaN     27.806189    992  1963.909033                10000
# 993        NaN    NaN     27.599434    993  1965.469769                10000
# 994        NaN    NaN     27.515755    994  1967.029965                10000
# 995        NaN    NaN     27.461697    995  1968.591086                10000
# 996        NaN    NaN     27.553694    996  1970.153969                10000
# 997        NaN    NaN     26.976622    997  1971.710842                10000
# 998        NaN    NaN     26.941587    998  1973.406972                10000
# 999        NaN    NaN     26.717937    999  1973.408644                10000
#
#      dist_w2    _timestamp
# 990      NaN  1.788766e+09
# 991      NaN  1.788766e+09
# 992      NaN  1.788766e+09
# 993      NaN  1.788766e+09
# 994      NaN  1.788766e+09
# 995      NaN  1.788766e+09
# 996      NaN  1.788766e+09
# 997      NaN  1.788766e+09
# 998      NaN  1.788766e+09
# 999      NaN  1.788766e+09
